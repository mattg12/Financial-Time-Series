# %% [markdown]
# ---
# <img src="../assets/grt_logo.png" style="float: left; margin: 20px; height: 55px">
#
# # Garton Research & Trading
#
# _September 4, 2019_
#
# ---
#
# ## Forecasting Short Term Volatility with Prophet
#
# ---
#
# **Context:** The purpose of this study is to use Facebook's [Prophet](https://facebook.github.io/prophet/) package to attempt to forecast short-term volatility, specfically the volatility of the broad U.S. stock market. The starting point will be to attempt to predict the level of the CBOE Volatility Index, or VIX, otherwise known as the 'fear index.'
#
# Source of VIX data: [CBOE website](http://www.cboe.com/data/historical-options-data)
#
# _Author: Matthew Garton_

# %%
# import necessary packages
import pandas as pd
from fbprophet import Prophet

pd.plotting.register_matplotlib_converters() # temporary fix to allow pandas plotting to work with prophet

# %%
# read in VIX data
vix = pd.read_csv('../data/vix.csv',
                  usecols=[0,2], # Only looking at the 'High' of the day
                  skiprows=2015,
                  header=0, names=['ds','y'])

# %%
# instantiate and fit model
m = Prophet()
m.fit(vix)

# make predictions
future_vix = m.make_future_dataframe(periods=365*5)
forecast = m.predict(future_vix)

# view predictions
fig1 = m.plot(forecast)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# **Notes:** Clearly it does not make sense, to forecast this far out with such a relatively small lookback period. This first example is contrived to highlight a problem I'll need to deal with in forecasting VIX. Prophet appears very sensitive to outliers, which results in two suboptimal outcomes:
#
# 1. The confidence bands around the forecast become untenably wide.
# 2. The trend is forced upward to accompdate the range of possible outcomes.
#
# Prophet's documentation included some examples and suggest removing outliers. However, for this kind of problem, that approach is inappropriate. I need to be able to make short-term forecasts while accounting for the fact that extreme outliers can appear with very little warning.

# %%
# shorter term predictions - 90 days only
vix_st = vix.tail(250)

# instantiate and fit model
m_st = Prophet()
m_st.fit(vix_st)

# make predictions
future_vix_st = m_st.make_future_dataframe(periods=90)
forecast_st = m_st.predict(future_vix_st)

# view predictions
fig1 = m_st.plot(forecast_st)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# **Note:** Interesting observation here in that the outliers themselves may be a useful indicator of a changepoint. Given the mean reverting nature of volatility, and the tendency of markets to enter a period of calm after a major dislocation, the presence of an outlier might be a good point to add in a changepoint. At the very least, we can be reasonably confident that after an outlier of a particular magnitude, the next direction of volatlity _should_ be to reverse and go down.
