# %% [markdown]
# ---
# <img src="../assets/android-chrome-192x192.png" style="float: left; margin: 20px; height: 55px">
#
# # Garton Research & Trading
#
# _August 16, 2019_
#
# ---
#
# ## Forecasting Futures Prices with LSTMs
#
# ---
#
# **Context:** The purpose of this study is to experiment with implementing Long Short Term Memory neural networks to predict futures prices. The data for this study consists of continuous futures contracts (generic first nearby with naive rolling method) from the Wiki Continuous Futures dataset on [Quandl](https://www.quandl.com/data/CHRIS-Wiki-Continuous-Futures). The specific markets I chose to use are based on the markets used in the original 'Turtle Traders' strategy (CITATION NEEDED).
#
# _Author: Matthew Garton_

# %%
# standard data science imports
import pandas as pd
import numpy as np
import datetime

# necessary for plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# keras imports
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, GRU
from keras.preprocessing.sequence import TimeseriesGenerator

from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Import and Preprocess Data

# %%
# import a dataset
sugar = pd.read_csv('../data/ICE_SB1.csv', 
                    usecols=['Date','Settle'], 
                    index_col='Date', 
                    parse_dates=True)

# %%
sugar.head()
# Out:
#             Settle
# Date
# 1961-01-04    2.90
# 1961-01-05    2.91
# 1961-01-06    2.97
# 1961-01-09    3.01
# 1961-01-10    3.02

# %%
sugar.plot(figsize=(10,7))
plt.title('Sugar Prices from 1961 to Present', fontsize=18);

# %% [markdown]
# ### Note on regimes and sampling
#
# It is clear that the full history here is dominated by a few significant regimes. My expectation is that the LSTM model will be trained on a relatively short time span to predict an even shorter one, so looking at several decades of data which include some extreme events is unlikely to be successful. So I will choose a more recent subsample of the data to look at. Starting in the year 2000, in the middle of a 'boring' regime may be reasonable. I'll have to return to this later, but for now I'm satisfied with ignoring the extreme inflation of the 70's and 80's (with the knowledge that my strategy would become invalid if such a regime were to reappear).

# %%
sugar = sugar['2000':]
sugar.plot(figsize=(10,7))
plt.title('Sugar Prices from 2000 to Present', fontsize=18);

# %% [markdown]
# ### Difference the data until approximately stationary

# %%
sugar['ds'] = sugar['Settle'].diff()
sugar['ds'].plot(figsize=(10,7))
plt.title('First-differencing of sugar prices', fontsize=18);

# %% [markdown]
# ### MinMaxScale the data to a range of (-1, 1)

# %%
s = sugar[['ds']].iloc[1:, :]

scaler = MinMaxScaler(feature_range=(-1, 1))
s = scaler.fit_transform(s)

print(s.shape)
# Out:
# (4672, 1)

# %% [markdown]
# ### Train/Test Split
#
# Split off the final 30% of the data as the test set. 30% is an arbitrary decision here, so it may be worth revisiting how different splits affect the results.

# %%
train_split = int(.7*s.shape[0])

train, test = s[0:train_split,:], s[train_split:s.shape[0],:]

# %% [markdown]
# ### Reshape Data for LSTM
#
# LSTM neural networks require input in a particular shape. Before I started using keras' TimeSeriesGenerator, I had to format the data manually to comply with LSTM. I have included below a (updated) code snippet of that functionality for reference. TimeSeriesGenerator is a time saver, but I find that manually working with the data helps me to not lose track of the transformations and to better understand what's going on.

# %%
# The following is based on a function I had used for LSTM
# preprocessing before I was aware of TimeSeriesGenerator
# I tested it out to verify that it accomplished the same result

#def format_ts(df, window_size = 3):    
#    '''
#    Return an time series formatted for LSTM
#    parameters
#    df: data frame of time series values
#    window_size: number of lags to use as features
#    
#    returns 
#    X: array of lagged values
#    y: target value
#    '''
#    
#    copy = df.copy()
#    
#    # for each row in the dataframe, add 'window size' columns,
#    # each one representing the subsequent period's observation
#    for i in range(window_size):
#        df = pd.concat([df, copy.shift(-(i + 1))], 
#                            axis = 1)
#       
#    df.dropna(axis=0, inplace=True)
#    X = np.array(df.iloc[:,0:window_size])
#    y = np.array(df.iloc[:, window_size])
#    
#    return X, y
#
# X, y = create_window(pd.DataFrame(train))

# %% [markdown]
# ### Build and train the LSTM

# %%
# set up generator
lags = 3
generator = TimeseriesGenerator(train, train, length=lags, batch_size=32)

# set up model
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(lags, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# fit model
history = model.fit_generator(generator, validation_data=test, steps_per_epoch=1, epochs=100, verbose=1);
# Out:
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.1161 - val_loss: 0.0309
# Epoch 2/100
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0184 - val_loss: 0.0298
# Epoch 3/100
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0112 - val_loss: 0.0287
# Epoch 4/100
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0308 - val_loss: 0.0275
# Epoch 5/100
# 1/1 [==============================] - 0s 281ms/step - loss: 0.0237 - val_loss: 0.0264
# Epoch 6/100
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0533 - val_loss: 0.0253
# Epoch 7/100
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0253 - val_loss: 0.0243
# Epoch 8/100
# 1/1 [==============================] - 0s 299ms/step - loss: 0.0146 - val_loss: 0.0233
# Epoch 9/100
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0256 - val_loss: 0.0223
# Epoch 10/100
# 1/1 [==============================] - 0s 295ms/step - loss: 0.0070 - val_loss: 0.0214
# Epoch 11/100
# 1/1 [==============================] - 0s 291ms/step - loss: 0.0056 - val_loss: 0.0205
# Epoch 12/100
# 1/1 [==============================] - 0s 341ms/step - loss: 0.0165 - val_loss: 0.0197
# Epoch 13/100
# 1/1 [==============================] - 0s 311ms/step - loss: 0.0437 - val_loss: 0.0189
# Epoch 14/100
# 1/1 [==============================] - 0s 292ms/step - loss: 0.0261 - val_loss: 0.0182
# Epoch 15/100
# 1/1 [==============================] - 0s 293ms/step - loss: 0.0142 - val_loss: 0.0175
# Epoch 16/100
# 1/1 [==============================] - 0s 297ms/step - loss: 0.0119 - val_loss: 0.0170
# Epoch 17/100
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0029 - val_loss: 0.0166
# Epoch 18/100
# 1/1 [==============================] - 0s 291ms/step - loss: 0.0054 - val_loss: 0.0163
# Epoch 19/100
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0228 - val_loss: 0.0161
# Epoch 20/100
# 1/1 [==============================] - 0s 293ms/step - loss: 0.0025 - val_loss: 0.0160
# Epoch 21/100
# 1/1 [==============================] - 0s 301ms/step - loss: 0.0022 - val_loss: 0.0161
# Epoch 22/100
# 1/1 [==============================] - 0s 312ms/step - loss: 0.0119 - val_loss: 0.0162
# Epoch 23/100
# 1/1 [==============================] - 0s 300ms/step - loss: 0.0282 - val_loss: 0.0164
# Epoch 24/100
# 1/1 [==============================] - 0s 293ms/step - loss: 0.0566 - val_loss: 0.0165
# Epoch 25/100
# 1/1 [==============================] - 0s 308ms/step - loss: 0.0049 - val_loss: 0.0166
# Epoch 26/100
# 1/1 [==============================] - 0s 299ms/step - loss: 0.0035 - val_loss: 0.0166
# Epoch 27/100
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0197 - val_loss: 0.0166
# Epoch 28/100
# 1/1 [==============================] - 0s 300ms/step - loss: 0.0097 - val_loss: 0.0166
# Epoch 29/100
# 1/1 [==============================] - 0s 283ms/step - loss: 0.0050 - val_loss: 0.0166
# Epoch 30/100
# 1/1 [==============================] - 0s 302ms/step - loss: 0.0083 - val_loss: 0.0166
# Epoch 31/100
# 1/1 [==============================] - 0s 347ms/step - loss: 0.0019 - val_loss: 0.0165
# Epoch 32/100
# 1/1 [==============================] - 0s 310ms/step - loss: 0.0018 - val_loss: 0.0164
# Epoch 33/100
# 1/1 [==============================] - 0s 326ms/step - loss: 0.0284 - val_loss: 0.0164
# Epoch 34/100
# 1/1 [==============================] - 0s 310ms/step - loss: 0.0148 - val_loss: 0.0163
# Epoch 35/100
# 1/1 [==============================] - 0s 307ms/step - loss: 0.0026 - val_loss: 0.0162
# Epoch 36/100
# 1/1 [==============================] - 0s 295ms/step - loss: 0.0034 - val_loss: 0.0161
# Epoch 37/100
# 1/1 [==============================] - 0s 302ms/step - loss: 0.0033 - val_loss: 0.0161
# Epoch 38/100
# 1/1 [==============================] - 0s 309ms/step - loss: 0.0055 - val_loss: 0.0160
# Epoch 39/100
# 1/1 [==============================] - 0s 319ms/step - loss: 0.0057 - val_loss: 0.0160
# Epoch 40/100
# 1/1 [==============================] - 0s 294ms/step - loss: 7.5509e-04 - val_loss: 0.0160
# Epoch 41/100
# 1/1 [==============================] - 0s 329ms/step - loss: 0.0602 - val_loss: 0.0160
# Epoch 42/100
# 1/1 [==============================] - 0s 293ms/step - loss: 0.0042 - val_loss: 0.0160
# Epoch 43/100
# 1/1 [==============================] - 0s 295ms/step - loss: 0.0038 - val_loss: 0.0160
# Epoch 44/100
# 1/1 [==============================] - 0s 300ms/step - loss: 0.0103 - val_loss: 0.0160
# Epoch 45/100
# 1/1 [==============================] - 0s 324ms/step - loss: 0.0048 - val_loss: 0.0160
# Epoch 46/100
# 1/1 [==============================] - 0s 294ms/step - loss: 6.6960e-04 - val_loss: 0.0160
# Epoch 47/100
# 1/1 [==============================] - 0s 314ms/step - loss: 0.0050 - val_loss: 0.0160
# Epoch 48/100
# 1/1 [==============================] - 0s 313ms/step - loss: 0.0014 - val_loss: 0.0160
# Epoch 49/100
# 1/1 [==============================] - 0s 301ms/step - loss: 0.0017 - val_loss: 0.0160
# Epoch 50/100
# 1/1 [==============================] - 0s 296ms/step - loss: 0.0391 - val_loss: 0.0160
# Epoch 51/100
# 1/1 [==============================] - 0s 307ms/step - loss: 0.0089 - val_loss: 0.0160
# Epoch 52/100
# 1/1 [==============================] - 0s 339ms/step - loss: 0.0032 - val_loss: 0.0160
# Epoch 53/100
# 1/1 [==============================] - 0s 304ms/step - loss: 0.0056 - val_loss: 0.0160
# Epoch 54/100
# 1/1 [==============================] - 0s 312ms/step - loss: 0.1366 - val_loss: 0.0160
# Epoch 55/100
# 1/1 [==============================] - 0s 295ms/step - loss: 8.2931e-04 - val_loss: 0.0160
# Epoch 56/100
# 1/1 [==============================] - 0s 292ms/step - loss: 0.0045 - val_loss: 0.0160
# Epoch 57/100
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0241 - val_loss: 0.0160
# Epoch 58/100
# 1/1 [==============================] - 0s 308ms/step - loss: 0.0032 - val_loss: 0.0160
# Epoch 59/100
# 1/1 [==============================] - 0s 295ms/step - loss: 0.0034 - val_loss: 0.0160
# Epoch 60/100
# 1/1 [==============================] - 0s 294ms/step - loss: 0.0023 - val_loss: 0.0160
# Epoch 61/100
# 1/1 [==============================] - 0s 295ms/step - loss: 0.0035 - val_loss: 0.0160
# Epoch 62/100
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0015 - val_loss: 0.0160
# Epoch 63/100
# 1/1 [==============================] - 0s 296ms/step - loss: 0.0019 - val_loss: 0.0160
# Epoch 64/100
# 1/1 [==============================] - 0s 292ms/step - loss: 0.0017 - val_loss: 0.0160
# Epoch 65/100
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0487 - val_loss: 0.0160
# Epoch 66/100
# 1/1 [==============================] - 0s 299ms/step - loss: 0.0691 - val_loss: 0.0160
# Epoch 67/100
# 1/1 [==============================] - 0s 296ms/step - loss: 0.0502 - val_loss: 0.0160
# Epoch 68/100
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0028 - val_loss: 0.0160
# Epoch 69/100
# 1/1 [==============================] - 0s 293ms/step - loss: 0.0189 - val_loss: 0.0160
# Epoch 70/100
# 1/1 [==============================] - 0s 333ms/step - loss: 0.0025 - val_loss: 0.0160
# Epoch 71/100
# 1/1 [==============================] - 0s 318ms/step - loss: 0.0120 - val_loss: 0.0160
# Epoch 72/100
# 1/1 [==============================] - 0s 313ms/step - loss: 0.0016 - val_loss: 0.0160
# Epoch 73/100
# 1/1 [==============================] - 0s 299ms/step - loss: 0.0048 - val_loss: 0.0160
# Epoch 74/100
# 1/1 [==============================] - 0s 318ms/step - loss: 0.0091 - val_loss: 0.0160
# Epoch 75/100
# 1/1 [==============================] - 0s 272ms/step - loss: 0.0023 - val_loss: 0.0160
# Epoch 76/100
# 1/1 [==============================] - 0s 300ms/step - loss: 0.0031 - val_loss: 0.0160
# Epoch 77/100
# 1/1 [==============================] - 0s 308ms/step - loss: 0.1195 - val_loss: 0.0160
# Epoch 78/100
# 1/1 [==============================] - 0s 304ms/step - loss: 0.0030 - val_loss: 0.0160
# Epoch 79/100
# 1/1 [==============================] - 0s 303ms/step - loss: 0.0206 - val_loss: 0.0160
# Epoch 80/100
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0223 - val_loss: 0.0160
# Epoch 81/100
# 1/1 [==============================] - 0s 306ms/step - loss: 0.0074 - val_loss: 0.0160
# Epoch 82/100
# 1/1 [==============================] - 0s 299ms/step - loss: 0.0028 - val_loss: 0.0160
# Epoch 83/100
# 1/1 [==============================] - 0s 299ms/step - loss: 0.0256 - val_loss: 0.0160
# Epoch 84/100
# 1/1 [==============================] - 0s 307ms/step - loss: 0.0014 - val_loss: 0.0160
# Epoch 85/100
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0217 - val_loss: 0.0160
# Epoch 86/100
# 1/1 [==============================] - 0s 307ms/step - loss: 0.0027 - val_loss: 0.0160
# Epoch 87/100
# 1/1 [==============================] - 0s 294ms/step - loss: 0.0056 - val_loss: 0.0160
# Epoch 88/100
# 1/1 [==============================] - 0s 302ms/step - loss: 0.0026 - val_loss: 0.0160
# Epoch 89/100
# 1/1 [==============================] - 0s 296ms/step - loss: 0.0015 - val_loss: 0.0160
# Epoch 90/100
# 1/1 [==============================] - 0s 336ms/step - loss: 0.0096 - val_loss: 0.0160
# Epoch 91/100
# 1/1 [==============================] - 0s 259ms/step - loss: 0.0129 - val_loss: 0.0160
# Epoch 92/100
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0123 - val_loss: 0.0160
# Epoch 93/100
# 1/1 [==============================] - 0s 325ms/step - loss: 0.0036 - val_loss: 0.0160
# Epoch 94/100
# 1/1 [==============================] - 0s 238ms/step - loss: 0.0205 - val_loss: 0.0160
# Epoch 95/100
# 1/1 [==============================] - 0s 297ms/step - loss: 0.0037 - val_loss: 0.0160
# Epoch 96/100
# 1/1 [==============================] - 0s 302ms/step - loss: 0.0117 - val_loss: 0.0160
# Epoch 97/100
# 1/1 [==============================] - 0s 304ms/step - loss: 0.0020 - val_loss: 0.0160
# Epoch 98/100
# 1/1 [==============================] - 0s 313ms/step - loss: 0.0017 - val_loss: 0.0160
# Epoch 99/100
# 1/1 [==============================] - 0s 303ms/step - loss: 0.0235 - val_loss: 0.0160
# Epoch 100/100
# 1/1 [==============================] - 0s 348ms/step - loss: 0.0745 - val_loss: 0.0160

# %% [markdown]
# ### Analyze results of model

# %%
plt.figure(figsize=(10,7))
plt.plot(history.history['loss'], label='Train loss')
plt.plot(history.history['val_loss'], label='Test loss')
plt.title('Results from LSTM model', fontsize=18)
plt.legend();

# %% [markdown]
# ### Forecasting with the model
#
# **Note:** to facilitate comparing predictions to actual data, I will need to reverse the transformations that I originally made to my data, so that I can ultimately plot 'prices' and 'predcited prices.'

# %%
# use model to predict
test = TimeseriesGenerator(train, train, length=lags, batch_size=32)
yhat = model.predict_generator(test)
model.evaluate_generator(test)
# Out:
# 0.015935018938398236
